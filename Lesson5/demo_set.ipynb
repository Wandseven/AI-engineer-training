# %%
a = {1, 2, 3, 4}
print(a)
# Out:
# {1, 2, 3, 4}

# %%
a = {1, 2, 1, 2, 1, 2}
print(a)
# Out:
# {1, 2}

# %%
a = [1, 3, 5, 7, 9, 7, 2]
b = set(a)
print(b)
# Out:
# {1, 2, 3, 5, 7, 9}

# %%
a = {1, 2, 3, 4, 5}
b = {4, 5, 6, 7, 8}

# %%
c = a.union(b)
print(c)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %%
d = a.intersection(b)
print(b)
# Out:
# {4, 5, 6, 7, 8}

# %%
e = a.difference(b)
print(e)
f = b.difference(a)
print(f)
# Out:
# {1, 2, 3}
# {8, 6, 7}
